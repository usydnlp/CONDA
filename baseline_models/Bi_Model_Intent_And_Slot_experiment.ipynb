# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('drive/My Drive/research/githubs/Bi-Model-Intent-And-Slot-master')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # first run

# %%
# !python train.py
# Out:
# Number of training samples:  29079
# Number of test samples:  9687
# Number of words:  11568
# Number of intent labels:  5
# Number of slot labels 8
# Slot(
#   (enc): slot_enc(
#     (embedding): Embedding(11568, 300)
#     (lstm): LSTM(300, 200, num_layers=2, batch_first=True, bidirectional=True)
#   )
#   (dec): slot_dec(
#     (lstm): LSTM(1000, 200)
#     (fc): Linear(in_features=200, out_features=8, bias=True)
#   )
# )
# Intent(
#   (enc): intent_enc(
#     (embedding): Embedding(11568, 300)
#     (lstm): LSTM(300, 200, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   )
#   (dec): intent_dec(
#     (lstm): LSTM(800, 200, batch_first=True)
#     (fc): Linear(in_features=200, out_features=5, bias=True)
#   )
# )
# Slot loss: 2660.8113 	 Intent loss: 48.4805
# Slot loss: 621.6506 	 Intent loss: 39.5168
# Slot loss: 229.4946 	 Intent loss: 30.1637
# Slot loss: 195.5122 	 Intent loss: 27.5221
# Slot loss: 186.6942 	 Intent loss: 28.1385
# ...

# %% [markdown]
# # second run

# %%
# !python train.py
# Out:
# Number of training samples:  29079
# Number of test samples:  9687
# Number of words:  11568
# Number of intent labels:  5
# Number of slot labels 8
# Slot(
#   (enc): slot_enc(
#     (embedding): Embedding(11568, 300)
#     (lstm): LSTM(300, 200, num_layers=2, batch_first=True, bidirectional=True)
#   )
#   (dec): slot_dec(
#     (lstm): LSTM(1000, 200)
#     (fc): Linear(in_features=200, out_features=8, bias=True)
#   )
# )
# Intent(
#   (enc): intent_enc(
#     (embedding): Embedding(11568, 300)
#     (lstm): LSTM(300, 200, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   )
#   (dec): intent_dec(
#     (lstm): LSTM(800, 200, batch_first=True)
#     (fc): Linear(in_features=200, out_features=5, bias=True)
#   )
# )
# Slot loss: 2472.5714 	 Intent loss: 49.7695
# Slot loss: 627.9742 	 Intent loss: 38.9744
# Slot loss: 251.3576 	 Intent loss: 30.3250
# Slot loss: 203.9775 	 Intent loss: 28.0100
# Slot loss: 192.6079 	 Intent loss: 27.5340
# ...

# %% [markdown]
# # for 45k dataset

# %%
# !python train.py
# Out:
# Number of training samples:  26921
# Number of test samples:  8974
# Number of words:  9093
# Number of intent labels:  4
# Number of slot labels 8
# Slot(
#   (enc): slot_enc(
#     (embedding): Embedding(9093, 300)
#     (lstm): LSTM(300, 200, num_layers=2, batch_first=True, bidirectional=True)
#   )
#   (dec): slot_dec(
#     (lstm): LSTM(1000, 200)
#     (fc): Linear(in_features=200, out_features=8, bias=True)
#   )
# )
# Intent(
#   (enc): intent_enc(
#     (embedding): Embedding(9093, 300)
#     (lstm): LSTM(300, 200, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   )
#   (dec): intent_dec(
#     (lstm): LSTM(800, 200, batch_first=True)
#     (fc): Linear(in_features=200, out_features=4, bias=True)
#   )
# )
# Slot loss: 2573.5383 	 Intent loss: 40.4496
# Slot loss: 669.9753 	 Intent loss: 33.4783
# Slot loss: 241.5161 	 Intent loss: 29.4812
# Slot loss: 209.4799 	 Intent loss: 28.2642
# Slot loss: 198.9194 	 Intent loss: 27.7806
# ...

# %% [markdown]
# # other try

# %%
# !python train.py

# %%
# !python train.py
# Out:
# Number of training samples:  29079
# Number of test samples:  9687
# Number of words:  11674
# Number of intent labels:  5
# Number of slot labels 8
# Slot(
#   (enc): slot_enc(
#     (embedding): Embedding(11674, 300)
#     (lstm): LSTM(300, 200, num_layers=2, batch_first=True, bidirectional=True)
#   )
#   (dec): slot_dec(
#     (lstm): LSTM(1000, 200)
#     (fc): Linear(in_features=200, out_features=8, bias=True)
#   )
# )
# Intent(
#   (enc): intent_enc(
#     (embedding): Embedding(11674, 300)
#     (lstm): LSTM(300, 200, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   )
#   (dec): intent_dec(
#     (lstm): LSTM(800, 200, batch_first=True)
#     (fc): Linear(in_features=200, out_features=5, bias=True)
#   )
# )
# Slot loss: 2508.5758 	 Intent loss: 47.9108
# Slot loss: 571.1764 	 Intent loss: 35.6177
# Slot loss: 231.0708 	 Intent loss: 29.6345
# Slot loss: 189.6949 	 Intent loss: 27.8388
# Slot loss: 179.6190 	 Intent loss: 26.3947
# ...
